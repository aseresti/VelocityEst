# %%
import vtk
import numpy as np
import glob
import os
import sys
from vtk.util.numpy_support import vtk_to_numpy, numpy_to_vtk

sys.path.append(os.path.pardir)
from old.utilities import ReadVTUFile, ThresholdInBetween, ThresholdByUpper, LargestConnectedRegion, WriteVTUFile, ReadVTKFile

# %%
input_path = "/Volumes/T7_Research/Kitagawa_CT_Amplified/Kitagawa_MieUniversity_AMPLIFIED_Patient_1/CTMPI"
FileNames = np.sort(np.array(glob.glob(f"{input_path}/*.dcm")))
N = 11
Images = np.array(np.split(FileNames, N))
